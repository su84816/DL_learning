# %%
from tensorflow.keras.datasets.cifar10 import load_data
(x_train, y_train), (x_test, y_test) = load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
# !!! (50000, 1) =/= (50000, )
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
trans = [
    "airplane",										
    "automobile",										
    "bird",										
    "cat",										
    "deer",										
    "dog",										
    "frog",										
    "horse",										
    "ship",										
    "truck",
]

# %%
import matplotlib.pyplot as plt
idx = 10000
print(trans[y_train[idx][0]])
plt.imshow(x_train[idx])
# Out:
# automobile

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
layers = [
    # CNN
    # 一個過濾器: 3 * 3 * 3(前一層通道數) * 64(過濾器數目) + 64(bias) = 1792
    Conv2D(64, 3, padding="same", activation="relu", input_shape=(32, 32, 3)),
    MaxPooling2D(),
    # 一個過濾器: 3 * 3 * 64(前一層通道數) * 128(過濾器數目) + 128(bias) = 73856
    Conv2D(128, 3, padding="same", activation="relu"),
    MaxPooling2D(),
    Conv2D(256, 3, padding="same", activation="relu"),
    MaxPooling2D(),
    Conv2D(512, 3, padding="same", activation="relu"),
    #這裡直接做GAP
    GlobalAveragePooling2D(),
    Dense(10, activation="softmax")
]
model = Sequential(layers)
model.summary(line_length=100)
# Out:
# Model: "sequential"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  conv2d (Conv2D)                             (None, 32, 32, 64)                      1792
#
#  max_pooling2d (MaxPooling2D)                (None, 16, 16, 64)                      0
#
#  conv2d_1 (Conv2D)                           (None, 16, 16, 128)                     73856
#
#  max_pooling2d_1 (MaxPooling2D)              (None, 8, 8, 128)                       0
#
#  conv2d_2 (Conv2D)                           (None, 8, 8, 256)                       295168
#
#  max_pooling2d_2 (MaxPooling2D)              (None, 4, 4, 256)                       0
#
#  conv2d_3 (Conv2D)                           (None, 4, 4, 512)                       1180160
#
#  global_average_pooling2d (GlobalAveragePool  (None, 512)                            0
#  ing2D)
#
#  dense (Dense)                               (None, 10)                              5130
#
# ====================================================================================================
# Total params: 1,556,106
# Trainable params: 1,556,106
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
# 一個輸出(二元分類): BinaryCrossEntropy p log 1/q + (1 - p) log 1/1-q
# 多個輸出(多元分類): CategoricalCrossEntropy pi log1/qi
from tensorflow.keras.losses import SparseCategoricalCrossentropy
model.compile(loss=SparseCategoricalCrossentropy(),
              # "adam"也可以
              optimizer="adam",
              metrics=["accuracy"])

# %%
x_train_norm = x_train / 255
x_test_norm = x_test / 255

# %%
# batch_size: 看多少筆, 做一次梯度下降(幾10~幾100)
# epochs: 所有資料看幾輪(負責結束訓練)
# batch_size=200
# 一epochs: 54000 / 200 = 270(次梯度下降)
# verbose=0(quiet) 1(default) 2(no bar)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ModelCheckpoint("cnn.h5", save_best_only=True)
]
model.fit(x_train_norm,
          y_train,
          batch_size=200,
          epochs=100,
          validation_split=0.1,
          verbose=2,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 225/225 - 39s - loss: 1.7098 - accuracy: 0.3632 - val_loss: 1.3846 - val_accuracy: 0.4886 - 39s/epoch - 174ms/step
# Epoch 2/100
# 225/225 - 8s - loss: 1.3218 - accuracy: 0.5207 - val_loss: 1.2153 - val_accuracy: 0.5492 - 8s/epoch - 38ms/step
# Epoch 3/100
# 225/225 - 8s - loss: 1.1302 - accuracy: 0.5966 - val_loss: 1.0530 - val_accuracy: 0.6278 - 8s/epoch - 38ms/step
# Epoch 4/100
# 225/225 - 9s - loss: 1.0041 - accuracy: 0.6446 - val_loss: 0.9289 - val_accuracy: 0.6676 - 9s/epoch - 38ms/step
# Epoch 5/100
# 225/225 - 9s - loss: 0.8992 - accuracy: 0.6833 - val_loss: 0.8632 - val_accuracy: 0.7044 - 9s/epoch - 38ms/step
# Epoch 6/100
# 225/225 - 9s - loss: 0.8178 - accuracy: 0.7129 - val_loss: 0.8497 - val_accuracy: 0.6956 - 9s/epoch - 38ms/step
# Epoch 7/100
# 225/225 - 9s - loss: 0.7427 - accuracy: 0.7382 - val_loss: 0.7732 - val_accuracy: 0.7354 - 9s/epoch - 38ms/step
# Epoch 8/100
# 225/225 - 9s - loss: 0.6801 - accuracy: 0.7611 - val_loss: 0.7302 - val_accuracy: 0.7468 - 9s/epoch - 38ms/step
# Epoch 9/100
# 225/225 - 8s - loss: 0.6212 - accuracy: 0.7840 - val_loss: 0.7982 - val_accuracy: 0.7302 - 8s/epoch - 38ms/step
# Epoch 10/100
# 225/225 - 9s - loss: 0.5760 - accuracy: 0.7995 - val_loss: 0.6905 - val_accuracy: 0.7588 - 9s/epoch - 38ms/step
# Epoch 11/100
# 225/225 - 9s - loss: 0.5240 - accuracy: 0.8170 - val_loss: 0.6597 - val_accuracy: 0.7728 - 9s/epoch - 38ms/step
# Epoch 12/100
# 225/225 - 8s - loss: 0.4763 - accuracy: 0.8344 - val_loss: 0.6895 - val_accuracy: 0.7648 - 8s/epoch - 38ms/step
# Epoch 13/100
# 225/225 - 9s - loss: 0.4294 - accuracy: 0.8518 - val_loss: 0.6219 - val_accuracy: 0.7904 - 9s/epoch - 38ms/step
# Epoch 14/100
# 225/225 - 8s - loss: 0.3966 - accuracy: 0.8626 - val_loss: 0.6434 - val_accuracy: 0.7834 - 8s/epoch - 38ms/step
# Epoch 15/100
# 225/225 - 8s - loss: 0.3485 - accuracy: 0.8786 - val_loss: 0.6750 - val_accuracy: 0.7868 - 8s/epoch - 37ms/step
# Epoch 16/100
# 225/225 - 8s - loss: 0.3105 - accuracy: 0.8929 - val_loss: 0.6700 - val_accuracy: 0.7936 - 8s/epoch - 38ms/step
# Epoch 17/100
# 225/225 - 8s - loss: 0.2793 - accuracy: 0.9036 - val_loss: 0.6567 - val_accuracy: 0.7928 - 8s/epoch - 38ms/step
# Epoch 18/100
# 225/225 - 8s - loss: 0.2460 - accuracy: 0.9150 - val_loss: 0.6366 - val_accuracy: 0.8018 - 8s/epoch - 38ms/step

# %%
model.evaluate(x_test_norm, y_test)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6693 - accuracy: 0.7749
# [0.6692962050437927, 0.7749000191688538]

# %%
pre = model.predict(x_test_norm).argmax(axis=1)
pre
# Out:
# array([3, 8, 8, ..., 5, 1, 7])

# %%
# (10000, 1)和(10000,)是兩回事 > 要和x欄位對齊才能使用
y_test_1d = y_test.reshape(-1)

# %%
# keras: y_test_cat sklearn: y_test
import pandas as pd
from sklearn.metrics import confusion_matrix
pre = model.predict(x_test_norm).argmax(axis=1)
mat = confusion_matrix(y_test_1d, pre)
pd.DataFrame(mat,
             index=["{}(正確)".format(trans[i]) for i in range(10)],
             columns=["{}(預測)".format(trans[i]) for i in range(10)])
# Out:
#                 airplane(預測)  automobile(預測)  ...  ship(預測)  truck(預測)
# airplane(正確)             830              13  ...        53         25
# automobile(正確)            14             897  ...        19         40
# bird(正確)                  68               3  ...         6          5
# cat(正確)                   18               5  ...         4          6
# deer(正確)                  16               1  ...         5          3
# dog(正確)                   10               3  ...         3          4
# frog(正確)                   4               0  ...         2          0
# horse(正確)                  9               2  ...         1          5
# ship(正確)                  53              25  ...       850         12
# truck(正確)                 28              79  ...        22        819
#
# [10 rows x 10 columns]

# %%
import numpy as np
# 找出True(預測錯誤)的位置
idx = np.nonzero(pre != y_test_1d)[0]
#y_test太多筆,所以只取前200筆
idx = idx[:200]
pre_false_label = y_test_1d[idx]
pre_false_pre = pre[idx]
pre_false_img = x_test[idx]

plt.figure(figsize=(15, 45))
width = 10
height = len(idx) // width + 1
for i in range(len(idx)):
    plt.subplot(height, width, i+1)
    t = "[O]:{}\n[P]:{}".format(trans[pre_false_label[i]], trans[pre_false_pre[i]])
    plt.title(t)
    plt.axis("off")
    plt.imshow(pre_false_img[i])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#網路上找圖做預測,一般訓練資料的圖片大小在200*200左右
import requests
# pillow
from PIL import Image
url = input("url:")
response = requests.get(url, stream=True)
#對拿到的圖片做規格化
img = Image.open(response.raw).convert("RGB").resize((32, 32))
img_np = np.array(img) / 255
# (32, 32, 3) -> (1, 32, 32, 3)
img_np = img_np.reshape(1, 32, 32, 3)
proba = model.predict(img_np)[0]
for p, n in zip(proba, trans):
    print(n, "的機率:", round(p, 3))
plt.imshow(img)
# Out:
# url:https://image.shutterstock.com/image-vector/cartoon-happy-little-bird-flying-260nw-1301242141.jpg
# airplane 的機率: 0.998
# automobile 的機率: 0.0
# bird 的機率: 0.002
# cat 的機率: 0.0
# deer 的機率: 0.0
# dog 的機率: 0.0
# frog 的機率: 0.0
# horse 的機率: 0.0
# ship 的機率: 0.0
# truck 的機率: 0.0
